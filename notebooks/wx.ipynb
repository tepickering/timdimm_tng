# %%
import ssl
import json
from urllib.request import urlopen

from astropy import units as u

# %%
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

page = urlopen('https://weather.monet.suth.saao.ac.za/api/sensors/', context=ctx)
data = json.loads(page.read().decode())

# %%
data
# Out:
# {'time': '2023-12-29T22:10:24Z',
#  'good': False,
#  'sensors': {'windspeed': {'good': True, 'value': 9.620000000000001},
#   'humid': {'good': False, 'value': 92.7},
#   'dewpoint': {'good': None, 'value': None},
#   'skytemp': {'good': False, 'value': -16.5},
#   'sunalt': {'good': True, 'value': -34.006737118531994},
#   'temp': {'good': None, 'value': 14.425},
#   'press': {'good': None, 'value': 824.2},
#   'winddir': {'good': None, 'value': 137.0},
#   'rain': {'good': False, 'value': 0.0}}}

# %%
data
# Out:
# [{'id': 50,
#   'station_id': 1,
#   'type_id': 17,
#   'good': None,
#   'since': None,
#   'delay_good': 0,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'average',
#   'station_name': 'Average values',
#   'type_code': 'dewpoint',
#   'type_name': 'Dew point',
#   'unit': '°',
#   'value': None},
#  {'id': 25,
#   'station_id': 1,
#   'type_id': 12,
#   'good': None,
#   'since': None,
#   'delay_good': 0,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'average',
#   'station_name': 'Average values',
#   'type_code': 'press',
#   'type_name': 'Pressure',
#   'unit': 'hPa',
#   'value': 823.0},
#  {'id': 26,
#   'station_id': 1,
#   'type_id': 13,
#   'good': None,
#   'since': None,
#   'delay_good': 0,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'average',
#   'station_name': 'Average values',
#   'type_code': 'rain',
#   'type_name': 'Raining',
#   'unit': '0/1',
#   'value': 0.0},
#  {'id': 22,
#   'station_id': 1,
#   'type_id': 9,
#   'good': None,
#   'since': None,
#   'delay_good': 0,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'average',
#   'station_name': 'Average values',
#   'type_code': 'humid',
#   'type_name': 'Relative humidity',
#   'unit': '%',
#   'value': 91.44},
#  {'id': 43,
#   'station_id': 1,
#   'type_id': 16,
#   'good': None,
#   'since': None,
#   'delay_good': 0,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'average',
#   'station_name': 'Average values',
#   'type_code': 'skytemp',
#   'type_name': 'Relative sky temperature',
#   'unit': '°C',
#   'value': -19.4},
#  {'id': 27,
#   'station_id': 1,
#   'type_id': 1,
#   'good': None,
#   'since': None,
#   'delay_good': 0,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'average',
#   'station_name': 'Average values',
#   'type_code': 'sunalt',
#   'type_name': 'Solar altitude',
#   'unit': '°',
#   'value': -32.0754455065147},
#  {'id': 21,
#   'station_id': 1,
#   'type_id': 8,
#   'good': None,
#   'since': None,
#   'delay_good': 0,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'average',
#   'station_name': 'Average values',
#   'type_code': 'temp',
#   'type_name': 'Temperature',
#   'unit': '°C',
#   'value': 13.795},
#  {'id': 23,
#   'station_id': 1,
#   'type_id': 10,
#   'good': None,
#   'since': None,
#   'delay_good': 0,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'average',
#   'station_name': 'Average values',
#   'type_code': 'winddir',
#   'type_name': 'Wind dir',
#   'unit': '°E of N',
#   'value': 105.0},
#  {'id': 24,
#   'station_id': 1,
#   'type_id': 11,
#   'good': None,
#   'since': None,
#   'delay_good': 0,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'average',
#   'station_name': 'Average values',
#   'type_code': 'windspeed',
#   'type_name': 'Wind speed',
#   'unit': 'km/h',
#   'value': 21.259999999999998},
#  {'id': 13,
#   'station_id': 5,
#   'type_id': 12,
#   'good': None,
#   'since': None,
#   'delay_good': 0,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'thiesws',
#   'station_name': 'MONET',
#   'type_code': 'press',
#   'type_name': 'Pressure',
#   'unit': 'hPa',
#   'value': 823.0},
#  {'id': 14,
#   'station_id': 5,
#   'type_id': 13,
#   'good': True,
#   'since': '2023-12-29T17:27:30.743Z',
#   'delay_good': 7200,
#   'delay_bad': 120,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'thiesws',
#   'station_name': 'MONET',
#   'type_code': 'rain',
#   'type_name': 'Raining',
#   'unit': '0/1',
#   'value': 0.0},
#  {'id': 10,
#   'station_id': 5,
#   'type_id': 9,
#   'good': False,
#   'since': '2023-12-29T20:05:47.999Z',
#   'delay_good': 1800,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'thiesws',
#   'station_name': 'MONET',
#   'type_code': 'humid',
#   'type_name': 'Relative humidity',
#   'unit': '%',
#   'value': 90.9},
#  {'id': 9,
#   'station_id': 5,
#   'type_id': 8,
#   'good': None,
#   'since': None,
#   'delay_good': 0,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'thiesws',
#   'station_name': 'MONET',
#   'type_code': 'temp',
#   'type_name': 'Temperature',
#   'unit': '°C',
#   'value': 13.8},
#  {'id': 11,
#   'station_id': 5,
#   'type_id': 10,
#   'good': None,
#   'since': None,
#   'delay_good': 0,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'thiesws',
#   'station_name': 'MONET',
#   'type_code': 'winddir',
#   'type_name': 'Wind dir',
#   'unit': '°E of N',
#   'value': 105.0},
#  {'id': 12,
#   'station_id': 5,
#   'type_id': 11,
#   'good': True,
#   'since': '2023-12-26T22:21:30.853Z',
#   'delay_good': 1200,
#   'delay_bad': 30,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'thiesws',
#   'station_name': 'MONET',
#   'type_code': 'windspeed',
#   'type_name': 'Wind speed',
#   'unit': 'km/h',
#   'value': 22.32},
#  {'id': 1,
#   'station_id': 3,
#   'type_id': 1,
#   'good': True,
#   'since': '2023-12-29T17:42:01.261Z',
#   'delay_good': 0,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'observer',
#   'station_name': 'Observer',
#   'type_code': 'sunalt',
#   'type_name': 'Solar altitude',
#   'unit': '°',
#   'value': -32.0754455065147},
#  {'id': 41,
#   'station_id': 10,
#   'type_id': 13,
#   'good': False,
#   'since': '2023-12-29T19:35:46.685Z',
#   'delay_good': 7200,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': '2023-12-29T23:44:28.473Z',
#   'average': True,
#   'active': True,
#   'station_code': 'suth',
#   'station_name': 'SuthWeather',
#   'type_code': 'rain',
#   'type_name': 'Raining',
#   'unit': '0/1',
#   'value': 0},
#  {'id': 38,
#   'station_id': 10,
#   'type_id': 9,
#   'good': False,
#   'since': '2023-12-29T20:05:48.253Z',
#   'delay_good': 1800,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'suth',
#   'station_name': 'SuthWeather',
#   'type_code': 'humid',
#   'type_name': 'Relative humidity',
#   'unit': '%',
#   'value': 91.98},
#  {'id': 42,
#   'station_id': 10,
#   'type_id': 16,
#   'good': False,
#   'since': '2023-12-26T19:44:33.327Z',
#   'delay_good': 1200,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'suth',
#   'station_name': 'SuthWeather',
#   'type_code': 'skytemp',
#   'type_name': 'Relative sky temperature',
#   'unit': '°C',
#   'value': -19.4},
#  {'id': 40,
#   'station_id': 10,
#   'type_id': 8,
#   'good': None,
#   'since': None,
#   'delay_good': 0,
#   'delay_bad': 0,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'suth',
#   'station_name': 'SuthWeather',
#   'type_code': 'temp',
#   'type_name': 'Temperature',
#   'unit': '°C',
#   'value': 13.79},
#  {'id': 39,
#   'station_id': 10,
#   'type_id': 11,
#   'good': True,
#   'since': '2023-12-28T14:22:28.166Z',
#   'delay_good': 1200,
#   'delay_bad': 30,
#   'bad_since': None,
#   'good_since': None,
#   'average': True,
#   'active': True,
#   'station_code': 'suth',
#   'station_name': 'SuthWeather',
#   'type_code': 'windspeed',
#   'type_name': 'Wind speed',
#   'unit': 'km/h',
#   'value': 20.2}]

# %%
with open("monet.json", "w") as f:
    json.dump(data, f, indent=4)
